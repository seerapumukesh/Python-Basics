# %% [markdown]
# ##### Python Indentation

# %%
# Indentation refers to the spaces at the beginning of a code line. Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
# Python uses indentation to indicate a block of code.

if 5 >2 :
    print('five is greater than two')  # String variables can be declared either by using single or double quotes
# Out:
# five is greater than two

# %%
if 5>2:
print('five is greater than two')

# The number of spaces is up to you as a programmer, the most common use is four, but it has to be at least one.
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error:
# Out:
#   File "<command-3848702639528387>", line 2
#     print('five is greater than two')
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ##### Variables

# %%
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). Rules for Python variables:
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

# %%
# Camel Case : 
# Each word, except the first, starts with a capital letter:
# myVariableName = "John"

# Pascal Case:
# Each word starts with a capital letter:
# MyVariableName = "John"

# Snake Case:
# Each word is separated by an underscore character:
# my_variable_name = "John"

# %%
# variables are created when you assign a value to it

x = 5
y = "Hello, World!"

print(x)
print(y)

x = "sally"  # Variables do not need to be declared with any particular type, and can even change type after they have been set.
print (x)
# Out:
# 5
# Hello, World!
# sally

# %%
# Python allows you to assign values to multiple variables in one line

x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# Unpack a Collection
# If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking.

fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z) # It will give spaces after each variable
# print(x + y + z)  # It will not give spaces after the variable which results "Pythonisawesome"
# Out:
# Python is awesome

# %%
# For numbers, the + character works as a mathematical operator:
x = 5
y = 10
z= "John"
print(x + y)
print (x+z)
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-168425248952269> in <cell line: 6>()
#       4 z= "John"
#       5 print(x + y)
# ----> 6 print (x+z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ###### Global Variables

# %%
# Variables that are created outside of a function as in all of the examples above are known as global variables
# Global variables can be used by everyone, both inside of functions and outside.

x = "awesome"   # Global variable

def myfunc():
  x = "fantastic"   # Local variable
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
# Normally, when you create a variable inside a function, that variable is local, and can only be used inside that function.
# To create a global variable inside a function, you can use the global keyword.

x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %% [markdown]
# ##### Data Types

# %%
# Python has the following data types built-in by default, in these categories:

# Text Type:	str  ---> "Hello World"
# Numeric Types:	int, float, complex --->20 , 20.5 , 1j
# Sequence Types:	list, tuple, range  ---> x = ["apple", "banana", "cherry"]	, x = ("apple", "banana", "cherry")	 ,   x = range(6)
# Mapping Type:	dict  --->x = {"name" : "John", "age" : 36}
# Set Types:	set, frozenset   --->x = {"apple", "banana", "cherry"}  , x = frozenset({"apple", "banana", "cherry"})
# Boolean Type:	bool  ---> True
# Binary Types:	bytes, bytearray, memoryview   ---> x = b"Hello" , 	x = bytearray(5) ,	x = memoryview(bytes(5))
# None Type:	NoneType   --->x = None

# %%
#Get the type of the data
x= 1.10
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# ###### Strings

# %%
# Get the character at position 1 (remember that the first character has the position 0)
a = "Hello, World!"
print(a[1])
# Out:
# e

# %%
#Loop through the letters in the word "banana"

for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
# The len() function returns the length of a string:

a = "Hello, World!"
print(len(a))
# Out:
# 13

# %%
# Check if "free" is present in the following text:

txt = "The best things in life are free!"
print("free" in txt)   # use 'not in' for opposite
# Out:
# True

# %%
# Print only if "free" is present:

txt = "The best things in life are free!"
if "free" in txt:     # use 'not in' for opposite  
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %%
# Slicing Strings

# Get the characters from position 2 to position 5 (not included):
a = "Hello, World!"
print(a[2:5])

# Get the characters from the start to position 5 (not included):
print(a[:5])

# Get the characters from position 2, and all the way to the end:
print(a[2:])

# Use negative indexes to start the slice from the end of the string
# Get the characters: From: "o" in "World!" position -5 To, but not included: "d" in "World!" position -2:
print(a[-5:-2])
# Out:
# llo
# Hello
# llo, World!
# orl

# %%
# Modify Strings

print(a.upper())  # turns into upper case letters
print(a.lower())  # turns into upper case letters
print(a.strip())  # The strip() method removes any whitespace from the beginning or the end:
print(a.replace("H","j"))  #The replace() method replaces a string with another string:
print(a.split(","))    # The split() method splits the string into substrings if it finds instances of the separator:
# Out:
# HELLO, WORLD!
# hello, world!
# Hello, World!
# jello, World!
# ['Hello', ' World!']

# %%
# String Concatenation

# Merge variable a with variable b into variable c:
a = "Hello"
b = "World"
c = a + b
print(c)

# add a space between them
c = a + " " +b
print(c)

#we cannot combine strings and numbers as above method, we can do that with below method

#Format - Strings

age = 30
txt = "My name is Mukesh, and I am {}"    #The format() method takes the passed arguments, formats them, and places them in the string where the placeholders {} are
print(txt.format(age))

# format method for multiple arguments
quantity = 3
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(quantity, itemno, price))

#You can use index numbers {0} to be sure the arguments are placed in the correct placeholders:
myorder = "I want to pay {2} dollars for {0} pieces of item {1}."
print(myorder.format(quantity, itemno, price))
# Out:
# HelloWorld
# Hello World
# My name is Mukesh, and I am 30
# I want 3 pieces of item 567 for 49.95 dollars.
# I want to pay 49.95 dollars for 3 pieces of item 567.

# %% [markdown]
# #####Casting

# %%
# If you want to specify the data type of a variable, this can be done with casting.
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print (z)
# Out:
# 3.0

# %% [markdown]
# ##### Random Number

# %%
# Python does not have a random function to make a random number but Python has a built-in module called random that can be used to make random numbers

import random 
print (random.randrange(1,10))
# Out:
# 5
